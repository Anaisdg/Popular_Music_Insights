# %%
import pandas as pd 
import json
import matplotlib.pyplot as plt 
import numpy as np

# %%
with open('pop_lyr_results/one_pop_results.json') as json_data:
    one = json.load(json_data)

# %%
with open('pop_lyr_results/two_pop_results.json') as json_data:
    two = json.load(json_data)

# %%
with open('pop_lyr_results/three_pop_results.json') as json_data:
    three = json.load(json_data)

# %%
with open('pop_lyr_results/four_pop_results.json') as json_data:
    four = json.load(json_data)

# %%
with open('pop_lyr_results/five_pop_results.json') as json_data:
    five = json.load(json_data)

# %%
with open('pop_lyr_results/six_pop_results.json') as json_data:
    six = json.load(json_data)

# %%
with open('pop_lyr_results/seven_pop_results.json') as json_data:
    seven = json.load(json_data)

# %%
one_personality = pd.DataFrame(one["personality"])
one_personality
# Out:
#       category                                           children  \
# 0  personality  [{'trait_id': 'facet_adventurousness', 'name':...
# 1  personality  [{'trait_id': 'facet_achievement_striving', 'n...
# 2  personality  [{'trait_id': 'facet_activity_level', 'name': ...
# 3  personality  [{'trait_id': 'facet_altruism', 'name': 'Altru...
# 4  personality  [{'trait_id': 'facet_anger', 'name': 'Fiery', ...
#
#                 name  percentile  raw_score  significant  \
# 0           Openness    0.666105   0.762354         True
# 1  Conscientiousness    0.223690   0.592614         True
# 2       Extraversion    0.223258   0.517037         True
# 3      Agreeableness    0.959440   0.811539         True
# 4    Emotional range    0.228898   0.425511         True
#
#                  trait_id
# 0           big5_openness
# 1  big5_conscientiousness
# 2       big5_extraversion
# 3      big5_agreeableness
# 4        big5_neuroticism

# %%
two_personality = pd.DataFrame(two["personality"])

# %%
three_personality = pd.DataFrame(three["personality"])

# %%
four_personality = pd.DataFrame(four["personality"])

# %%
five_personality = pd.DataFrame(five["personality"])

# %%
six_personality = pd.DataFrame(six["personality"])

# %%
seven_personality = pd.DataFrame(seven["personality"])

# %%
df1 = one_personality[["name","percentile"]]

# %%
df2 = two_personality[["name","percentile"]]

# %%
df3 = three_personality[["name","percentile"]]

# %%
df4 = four_personality[["name","percentile"]]

# %%
df5 = five_personality[["name","percentile"]]

# %%
df6 = six_personality[["name","percentile"]]

# %%
df7 = seven_personality[["name","percentile"]]

# %%
combined_scores_df = df1.merge(df2,on='name').merge(df3,on='name').merge(df4,on='name').merge(df5,on='name').merge(df6,on='name').merge(df7,on='name')

# %%
combined_scores_df
# Out:
#                 name  percentile_x  percentile_y  percentile_x  percentile_y  \
# 0           Openness      0.666105      0.884141      0.891219      0.576831
# 1  Conscientiousness      0.223690      0.351397      0.868646      0.643681
# 2       Extraversion      0.223258      0.494826      0.910728      0.835595
# 3      Agreeableness      0.959440      0.563526      0.996069      0.922933
# 4    Emotional range      0.228898      0.452872      0.664031      0.358765
#
#    percentile_x  percentile_y  percentile
# 0      0.412710      0.458436    0.615390
# 1      0.818852      0.648523    0.833320
# 2      0.551050      0.441434    0.977951
# 3      0.895823      0.865537    0.897116
# 4      0.396121      0.295176    0.755327

# %%
values = combined_scores_df.drop('name', axis=1)
values
# Out:
#    percentile_x  percentile_y  percentile_x  percentile_y  percentile_x  \
# 0      0.666105      0.884141      0.891219      0.576831      0.412710
# 1      0.223690      0.351397      0.868646      0.643681      0.818852
# 2      0.223258      0.494826      0.910728      0.835595      0.551050
# 3      0.959440      0.563526      0.996069      0.922933      0.895823
# 4      0.228898      0.452872      0.664031      0.358765      0.396121
#
#    percentile_y  percentile
# 0      0.458436    0.615390
# 1      0.648523    0.833320
# 2      0.441434    0.977951
# 3      0.865537    0.897116
# 4      0.295176    0.755327

# %%
timepoint = [1957,1967,1977,1987,1997,2007,2017]
length = np.arange(0,len(values),1)
labels = ["Openness",
          "Consienctiousness",
          "Extraversion",
          "Aggreeableness",
          "Emotional range"]

percentile=[]

for row in values.iterrows():
    index, data = row
    percentile.append(data.tolist())

# %%
plt.figure(figsize=(10,10))
[plt.scatter(timepoint, percentile[x]) for x in length]
plt.legend(loc='upper left', shadow=True)
[plt.plot(timepoint, percentile[x], linestyle= 'dashed', linewidth=1, label = labels[x]) for x in length]
plt.title("Emotional Response over Time")
plt.xlabel("Time")
plt.ylabel("Percentile Score")
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <h1><strong> In depth analysis complete data retrieval </strong></h1>

# %%
one_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in one["personality"] ]
one_full = pd.DataFrame(one_depth)
one_full.columns= [["Emotion", "1957"]]

# %%
one_full
# Out:
#                   Emotion      1957
# 0         Adventurousness  0.591354
# 1    Achievement striving  0.248446
# 2          Activity level  0.249253
# 3                Altruism  0.969342
# 4                   Fiery  0.222398
# 5      Artistic interests  0.997246
# 6            Cautiousness  0.264013
# 7           Assertiveness  0.189563
# 8             Cooperation  0.732201
# 9          Prone to worry  0.647707
# 10           Emotionality  0.991583
# 11            Dutifulness  0.524537
# 12           Cheerfulness  0.896944
# 13                Modesty  0.956906
# 14             Melancholy  0.858863
# 15            Imagination  0.923417
# 16            Orderliness  0.467707
# 17     Excitement-seeking  0.716892
# 18         Uncompromising  0.895374
# 19           Immoderation  0.600418
# 20              Intellect  0.859458
# 21        Self-discipline  0.250943
# 22               Outgoing  0.645136
# 23               Sympathy  0.986779
# 24     Self-consciousness  0.363443
# 25  Authority-challenging  0.533058
# 26          Self-efficacy  0.171545
# 27         Gregariousness  0.437092
# 28                  Trust  0.250603
# 29  Susceptible to stress  0.797852

# %%
two_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in two["personality"]]
two_full = pd.DataFrame(two_depth)
two_full.columns= [["Emotion", "1967"]]
three_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in three["personality"] ]
three_full = pd.DataFrame(three_depth)
three_full.columns= [["Emotion", "1977"]]
four_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in four["personality"] ]
four_full = pd.DataFrame(four_depth)
four_full.columns= [["Emotion", "1987"]]
five_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in five["personality"] ]
five_full = pd.DataFrame(five_depth)
five_full.columns= [["Emotion", "1997"]]
six_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in six["personality"] ]
six_full = pd.DataFrame(six_depth)
six_full.columns= [["Emotion", "2007"]]
seven_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in seven["personality"] ]
seven_full = pd.DataFrame(seven_depth)
seven_full.columns= [["Emotion", "2017"]]

# %%
two_full
# Out:
#                   Emotion      1967
# 0         Adventurousness  0.858989
# 1    Achievement striving  0.160298
# 2          Activity level  0.139885
# 3                Altruism  0.170523
# 4                   Fiery  0.402417
# 5      Artistic interests  0.995507
# 6            Cautiousness  0.625442
# 7           Assertiveness  0.076746
# 8             Cooperation  0.424872
# 9          Prone to worry  0.321111
# 10           Emotionality  0.553540
# 11            Dutifulness  0.083078
# 12           Cheerfulness  0.682409
# 13                Modesty  0.556996
# 14             Melancholy  0.570662
# 15            Imagination  0.983799
# 16            Orderliness  0.792234
# 17     Excitement-seeking  0.648004
# 18         Uncompromising  0.622572
# 19           Immoderation  0.717910
# 20              Intellect  0.895127
# 21        Self-discipline  0.131801
# 22               Outgoing  0.339127
# 23               Sympathy  0.836963
# 24     Self-consciousness  0.487972
# 25  Authority-challenging  0.952697
# 26          Self-efficacy  0.064391
# 27         Gregariousness  0.317948
# 28                  Trust  0.288434
# 29  Susceptible to stress  0.437232

# %%
combined = one_full.merge(two_full).merge(three_full).merge(four_full).merge(five_full).merge(six_full).merge(seven_full)
combined
# Out:
#                   Emotion      1957      1967      1977      1987      1997  \
# 0         Adventurousness  0.591354  0.858989  0.953183  0.914622  0.976461
# 1    Achievement striving  0.248446  0.160298  0.563011  0.218695  0.528630
# 2          Activity level  0.249253  0.139885  0.318582  0.183012  0.469747
# 3                Altruism  0.969342  0.170523  0.897855  0.929274  0.912282
# 4                   Fiery  0.222398  0.402417  0.047598  0.369100  0.112486
# 5      Artistic interests  0.997246  0.995507  0.997583  0.948777  0.980028
# 6            Cautiousness  0.264013  0.625442  0.850119  0.041879  0.507242
# 7           Assertiveness  0.189563  0.076746  0.132404  0.554800  0.374116
# 8             Cooperation  0.732201  0.424872  0.943095  0.361922  0.707173
# 9          Prone to worry  0.647707  0.321111  0.073918  0.485198  0.193814
# 10           Emotionality  0.991583  0.553540  0.961172  0.984419  0.961875
# 11            Dutifulness  0.524537  0.083078  0.494300  0.233500  0.492575
# 12           Cheerfulness  0.896944  0.682409  0.983902  0.979880  0.982336
# 13                Modesty  0.956906  0.556996  0.979432  0.864602  0.971665
# 14             Melancholy  0.858863  0.570662  0.251435  0.639149  0.528766
# 15            Imagination  0.923417  0.983799  0.780633  0.900895  0.807556
# 16            Orderliness  0.467707  0.792234  0.938559  0.661332  0.654121
# 17     Excitement-seeking  0.716892  0.648004  0.458910  0.922331  0.820011
# 18         Uncompromising  0.895374  0.622572  0.996009  0.834137  0.985415
# 19           Immoderation  0.600418  0.717910  0.294349  0.569399  0.279401
# 20              Intellect  0.859458  0.895127  0.883433  0.594039  0.740597
# 21        Self-discipline  0.250943  0.131801  0.776278  0.298209  0.683430
# 22               Outgoing  0.645136  0.339127  0.765327  0.796835  0.604873
# 23               Sympathy  0.986779  0.836963  0.974253  0.834234  0.911343
# 24     Self-consciousness  0.363443  0.487972  0.095030  0.166892  0.286803
# 25  Authority-challenging  0.533058  0.952697  0.489730  0.219880  0.199848
# 26          Self-efficacy  0.171545  0.064391  0.133230  0.370997  0.315636
# 27         Gregariousness  0.437092  0.317948  0.675015  0.797037  0.540112
# 28                  Trust  0.250603  0.288434  0.339645  0.101113  0.280070
# 29  Susceptible to stress  0.797852  0.437232  0.376920  0.630579  0.537419
#
#         2007      2017
# 0   0.957936  0.991357
# 1   0.157810  0.336593
# 2   0.166704  0.381874
# 3   0.814335  0.435326
# 4   0.130385  0.105708
# 5   0.947647  0.961649
# 6   0.199750  0.434592
# 7   0.322875  0.529653
# 8   0.561539  0.471616
# 9   0.286560  0.045056
# 10  0.913591  0.505751
# 11  0.201476  0.133149
# 12  0.967445  0.995972
# 13  0.901459  0.603075
# 14  0.612859  0.195645
# 15  0.711436  0.654597
# 16  0.453168  0.961864
# 17  0.872371  0.825269
# 18  0.906252  0.886478
# 19  0.680797  0.349904
# 20  0.785678  0.568592
# 21  0.357243  0.846395
# 22  0.620166  0.948681
# 23  0.741859  0.453398
# 24  0.318665  0.043605
# 25  0.517274  0.340419
# 26  0.120144  0.327034
# 27  0.740739  0.964863
# 28  0.104646  0.174292
# 29  0.580427  0.111108

# %%
combined.to_csv("pop_combined.csv")

# %%
transposed = combined.T
# transposed.columns = transposed.iloc[0]
transposed.reset_index(inplace=True)
transposed
# Out:
#    level_0                0                     1               2         3  \
# 0  Emotion  Adventurousness  Achievement striving  Activity level  Altruism
# 1     1957         0.591354              0.248446        0.249253  0.969342
# 2     1967         0.858989              0.160298        0.139885  0.170523
# 3     1977         0.953183              0.563011        0.318582  0.897855
# 4     1987         0.914622              0.218695        0.183012  0.929274
# 5     1997         0.976461               0.52863        0.469747  0.912282
# 6     2007         0.957936               0.15781        0.166704  0.814335
# 7     2017         0.991357              0.336593        0.381874  0.435326
#
#           4                   5             6              7            8  \
# 0     Fiery  Artistic interests  Cautiousness  Assertiveness  Cooperation
# 1  0.222398            0.997246      0.264013       0.189563     0.732201
# 2  0.402417            0.995507      0.625442      0.0767456     0.424872
# 3  0.047598            0.997583      0.850119       0.132404     0.943095
# 4    0.3691            0.948777     0.0418793         0.5548     0.361922
# 5  0.112486            0.980028      0.507242       0.374116     0.707173
# 6  0.130385            0.947647       0.19975       0.322875     0.561539
# 7  0.105708            0.961649      0.434592       0.529653     0.471616
#
#            ...                   20               21        22        23  \
# 0          ...            Intellect  Self-discipline  Outgoing  Sympathy
# 1          ...             0.859458         0.250943  0.645136  0.986779
# 2          ...             0.895127         0.131801  0.339127  0.836963
# 3          ...             0.883433         0.776278  0.765327  0.974253
# 4          ...             0.594039         0.298209  0.796835  0.834234
# 5          ...             0.740597          0.68343  0.604873  0.911343
# 6          ...             0.785678         0.357243  0.620166  0.741859
# 7          ...             0.568592         0.846395  0.948681  0.453398
#
#                    24                     25             26              27  \
# 0  Self-consciousness  Authority-challenging  Self-efficacy  Gregariousness
# 1            0.363443               0.533058       0.171545        0.437092
# 2            0.487972               0.952697      0.0643905        0.317948
# 3           0.0950304                0.48973        0.13323        0.675015
# 4            0.166892                0.21988       0.370997        0.797037
# 5            0.286803               0.199848       0.315636        0.540112
# 6            0.318665               0.517274       0.120144        0.740739
# 7           0.0436054               0.340419       0.327034        0.964863
#
#          28                     29
# 0     Trust  Susceptible to stress
# 1  0.250603               0.797852
# 2  0.288434               0.437232
# 3  0.339645                0.37692
# 4  0.101113               0.630579
# 5   0.28007               0.537419
# 6  0.104646               0.580427
# 7  0.174292               0.111108
#
# [8 rows x 31 columns]

# %%
new_header = transposed.iloc[0] #grab the first row for the header
transposed = transposed[1:] #take the data less the header row
transposed.columns = new_header

# %%
transposed
# Out:
# 0 Emotion Adventurousness Achievement striving Activity level  Altruism  \
# 1    1957        0.591354             0.248446       0.249253  0.969342
# 2    1967        0.858989             0.160298       0.139885  0.170523
# 3    1977        0.953183             0.563011       0.318582  0.897855
# 4    1987        0.914622             0.218695       0.183012  0.929274
# 5    1997        0.976461              0.52863       0.469747  0.912282
# 6    2007        0.957936              0.15781       0.166704  0.814335
# 7    2017        0.991357             0.336593       0.381874  0.435326
#
# 0     Fiery Artistic interests Cautiousness Assertiveness Cooperation  \
# 1  0.222398           0.997246     0.264013      0.189563    0.732201
# 2  0.402417           0.995507     0.625442     0.0767456    0.424872
# 3  0.047598           0.997583     0.850119      0.132404    0.943095
# 4    0.3691           0.948777    0.0418793        0.5548    0.361922
# 5  0.112486           0.980028     0.507242      0.374116    0.707173
# 6  0.130385           0.947647      0.19975      0.322875    0.561539
# 7  0.105708           0.961649     0.434592      0.529653    0.471616
#
# 0          ...          Intellect Self-discipline  Outgoing  Sympathy  \
# 1          ...           0.859458        0.250943  0.645136  0.986779
# 2          ...           0.895127        0.131801  0.339127  0.836963
# 3          ...           0.883433        0.776278  0.765327  0.974253
# 4          ...           0.594039        0.298209  0.796835  0.834234
# 5          ...           0.740597         0.68343  0.604873  0.911343
# 6          ...           0.785678        0.357243  0.620166  0.741859
# 7          ...           0.568592        0.846395  0.948681  0.453398
#
# 0 Self-consciousness Authority-challenging Self-efficacy Gregariousness  \
# 1           0.363443              0.533058      0.171545       0.437092
# 2           0.487972              0.952697     0.0643905       0.317948
# 3          0.0950304               0.48973       0.13323       0.675015
# 4           0.166892               0.21988      0.370997       0.797037
# 5           0.286803              0.199848      0.315636       0.540112
# 6           0.318665              0.517274      0.120144       0.740739
# 7          0.0436054              0.340419      0.327034       0.964863
#
# 0     Trust Susceptible to stress
# 1  0.250603              0.797852
# 2  0.288434              0.437232
# 3  0.339645               0.37692
# 4  0.101113              0.630579
# 5   0.28007              0.537419
# 6  0.104646              0.580427
# 7  0.174292              0.111108
#
# [7 rows x 31 columns]

# %%
transposed.rename(columns={transposed.columns[0]:"Year"})
transposed
# Out:
# 0 Emotion Adventurousness Achievement striving Activity level  Altruism  \
# 1    1957        0.591354             0.248446       0.249253  0.969342
# 2    1967        0.858989             0.160298       0.139885  0.170523
# 3    1977        0.953183             0.563011       0.318582  0.897855
# 4    1987        0.914622             0.218695       0.183012  0.929274
# 5    1997        0.976461              0.52863       0.469747  0.912282
# 6    2007        0.957936              0.15781       0.166704  0.814335
# 7    2017        0.991357             0.336593       0.381874  0.435326
#
# 0     Fiery Artistic interests Cautiousness Assertiveness Cooperation  \
# 1  0.222398           0.997246     0.264013      0.189563    0.732201
# 2  0.402417           0.995507     0.625442     0.0767456    0.424872
# 3  0.047598           0.997583     0.850119      0.132404    0.943095
# 4    0.3691           0.948777    0.0418793        0.5548    0.361922
# 5  0.112486           0.980028     0.507242      0.374116    0.707173
# 6  0.130385           0.947647      0.19975      0.322875    0.561539
# 7  0.105708           0.961649     0.434592      0.529653    0.471616
#
# 0          ...          Intellect Self-discipline  Outgoing  Sympathy  \
# 1          ...           0.859458        0.250943  0.645136  0.986779
# 2          ...           0.895127        0.131801  0.339127  0.836963
# 3          ...           0.883433        0.776278  0.765327  0.974253
# 4          ...           0.594039        0.298209  0.796835  0.834234
# 5          ...           0.740597         0.68343  0.604873  0.911343
# 6          ...           0.785678        0.357243  0.620166  0.741859
# 7          ...           0.568592        0.846395  0.948681  0.453398
#
# 0 Self-consciousness Authority-challenging Self-efficacy Gregariousness  \
# 1           0.363443              0.533058      0.171545       0.437092
# 2           0.487972              0.952697     0.0643905       0.317948
# 3          0.0950304               0.48973       0.13323       0.675015
# 4           0.166892               0.21988      0.370997       0.797037
# 5           0.286803              0.199848      0.315636       0.540112
# 6           0.318665              0.517274      0.120144       0.740739
# 7          0.0436054              0.340419      0.327034       0.964863
#
# 0     Trust Susceptible to stress
# 1  0.250603              0.797852
# 2  0.288434              0.437232
# 3  0.339645               0.37692
# 4  0.101113              0.630579
# 5   0.28007              0.537419
# 6  0.104646              0.580427
# 7  0.174292              0.111108
#
# [7 rows x 31 columns]

# %%
plt.figure(figsize=(10,10))
transposed.plot()
plt.show()

# %%
plt.figure(figsize=(30,30))
[plt.scatter(transposed["Emotion"], transposed.iloc[:,x]) for x in range(1,31)]
plt.legend(loc='upper left', shadow=True)
[plt.plot(transposed["Emotion"], transposed.iloc[:,x], linestyle= 'dashed', linewidth=1) for x in range(1,31)]
plt.title("Emotional Response over Time")
plt.xlabel("Time")
plt.ylabel("Percentile Score")
# plt.legend(loc='best')
plt.grid()
plt.show()

# %%
transposed.to_csv("pop_full.csv")
