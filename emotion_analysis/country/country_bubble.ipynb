# %%
import pandas as pd
import numpy as np
import time

# %%
combined = pd.read_csv("country_combined.csv")
combined = combined.drop(combined.columns[0], axis=1)
combined
# Out:
#                   Emotion      1957      1967      1977      1987      1997  \
# 0         Adventurousness  0.419209  0.656106  0.713257  0.657750  0.774223
# 1    Achievement striving  0.198338  0.332933  0.246229  0.423422  0.232846
# 2          Activity level  0.070753  0.242325  0.274652  0.386946  0.093448
# 3                Altruism  0.617536  0.952677  0.932543  0.698302  0.767263
# 4                   Fiery  0.366635  0.236679  0.404380  0.242286  0.220092
# 5      Artistic interests  0.952567  0.966113  0.993957  0.948897  0.987051
# 6            Cautiousness  0.350478  0.316309  0.108201  0.469585  0.477823
# 7           Assertiveness  0.262479  0.296851  0.265433  0.406554  0.118832
# 8             Cooperation  0.428054  0.568653  0.425332  0.449816  0.741578
# 9          Prone to worry  0.265751  0.311579  0.652427  0.234461  0.345017
# 10           Emotionality  0.779701  0.968929  0.993901  0.818191  0.954436
# 11            Dutifulness  0.244809  0.573516  0.279596  0.363267  0.469006
# 12           Cheerfulness  0.843149  0.889790  0.919209  0.917868  0.936883
# 13                Modesty  0.768131  0.952343  0.842506  0.727188  0.943907
# 14             Melancholy  0.656347  0.796982  0.923414  0.543163  0.633252
# 15            Imagination  0.774777  0.847428  0.981912  0.894250  0.728428
# 16            Orderliness  0.602848  0.450091  0.292180  0.719417  0.463899
# 17     Excitement-seeking  0.519653  0.588398  0.873147  0.699738  0.520615
# 18         Uncompromising  0.860910  0.946642  0.883186  0.892281  0.975414
# 19           Immoderation  0.707053  0.742497  0.865174  0.691175  0.628511
# 20              Intellect  0.925981  0.899389  0.920334  0.778564  0.749384
# 21        Self-discipline  0.242384  0.305765  0.135178  0.460285  0.322776
# 22               Outgoing  0.404178  0.618477  0.494417  0.793354  0.314083
# 23               Sympathy  0.898406  0.980114  0.966230  0.863522  0.808437
# 24     Self-consciousness  0.368925  0.244523  0.402067  0.158536  0.470274
# 25  Authority-challenging  0.476386  0.310181  0.501954  0.438899  0.461346
# 26          Self-efficacy  0.142488  0.190840  0.211125  0.363249  0.052425
# 27         Gregariousness  0.213024  0.466638  0.575564  0.819443  0.214140
# 28                  Trust  0.051975  0.190821  0.134079  0.326971  0.071042
# 29  Susceptible to stress  0.541732  0.565897  0.839845  0.325169  0.734967
#
#         2007      2017
# 0   0.789262  0.913003
# 1   0.391612  0.463470
# 2   0.215199  0.424038
# 3   0.949093  0.781625
# 4   0.047625  0.164191
# 5   0.961926  0.956611
# 6   0.567646  0.309557
# 7   0.455018  0.554704
# 8   0.773606  0.507215
# 9   0.138555  0.114335
# 10  0.976508  0.857226
# 11  0.594128  0.376073
# 12  0.950333  0.997073
# 13  0.873517  0.761543
# 14  0.365453  0.321872
# 15  0.652173  0.718518
# 16  0.545229  0.752254
# 17  0.563789  0.862802
# 18  0.967845  0.941394
# 19  0.749250  0.610284
# 20  0.877065  0.676429
# 21  0.427516  0.748113
# 22  0.687902  0.915825
# 23  0.942172  0.716432
# 24  0.190374  0.069760
# 25  0.578633  0.180439
# 26  0.186355  0.374745
# 27  0.659183  0.883686
# 28  0.310049  0.146317
# 29  0.348741  0.224006

# %%
colors = {'color':['#e6194b', '#3cb44b', '#ffe119', '#0082c8', '#f58231','#911eb4','#46f0f0','#f032e6','#d2f53c','#fabebe','#008080','#e6beff','#aa6e28','#fffac8','#800000','#aaffc3','#808000','#ffd8b1','#000080','#808080','#000000', '#B06A3F', '#F84EB8', '#074D26', '#586185', '#A0C1B1', '#ECF190', '##9ACBEA', '#662584', '##700C05']} 
len(colors)
colors_df = pd.DataFrame(colors)
colors_df['Emotion'] = combined['Emotion']
colors_df.head()
# Out:
#      color               Emotion
# 0  #e6194b       Adventurousness
# 1  #3cb44b  Achievement striving
# 2  #ffe119        Activity level
# 3  #0082c8              Altruism
# 4  #f58231                 Fiery

# %%
df = pd.melt(combined, 
            id_vars='Emotion', 
            value_vars=list(combined.columns[1:]), # list of the years
            var_name='years', 
            value_name='percentile',
            )
df.head()
# Out:
#                 Emotion years  percentile
# 0       Adventurousness  1957    0.419209
# 1  Achievement striving  1957    0.198338
# 2        Activity level  1957    0.070753
# 3              Altruism  1957    0.617536
# 4                 Fiery  1957    0.366635

# %%
result = df.sort_values(['Emotion', "years"], ascending=True)
result.head()
# Out:
#                   Emotion years  percentile
# 1    Achievement striving  1957    0.198338
# 31   Achievement striving  1967    0.332933
# 61   Achievement striving  1977    0.246229
# 91   Achievement striving  1987    0.423422
# 121  Achievement striving  1997    0.232846

# %%
position = pd.DataFrame(np.arange(1, len(combined)+1, 1))
position = position.rename(columns={position.columns.values[0]:"postion"})
position["Emotion"] = df["Emotion"]
position
# Out:
#     postion                Emotion
# 0         1        Adventurousness
# 1         2   Achievement striving
# 2         3         Activity level
# 3         4               Altruism
# 4         5                  Fiery
# 5         6     Artistic interests
# 6         7           Cautiousness
# 7         8          Assertiveness
# 8         9            Cooperation
# 9        10         Prone to worry
# 10       11           Emotionality
# 11       12            Dutifulness
# 12       13           Cheerfulness
# 13       14                Modesty
# 14       15             Melancholy
# 15       16            Imagination
# 16       17            Orderliness
# 17       18     Excitement-seeking
# 18       19         Uncompromising
# 19       20           Immoderation
# 20       21              Intellect
# 21       22        Self-discipline
# 22       23               Outgoing
# 23       24               Sympathy
# 24       25     Self-consciousness
# 25       26  Authority-challenging
# 26       27          Self-efficacy
# 27       28         Gregariousness
# 28       29                  Trust
# 29       30  Susceptible to stress

# %%
result["size"]=result["percentile"]
result["genre"]="Pop"
result = result.merge(position, on="Emotion")
result = result.merge(colors_df, on = "Emotion")
dataset = result
dataset
# Out:
#                    Emotion years  percentile      size genre  postion  \
# 0     Achievement striving  1957    0.198338  0.198338   Pop        2
# 1     Achievement striving  1967    0.332933  0.332933   Pop        2
# 2     Achievement striving  1977    0.246229  0.246229   Pop        2
# 3     Achievement striving  1987    0.423422  0.423422   Pop        2
# 4     Achievement striving  1997    0.232846  0.232846   Pop        2
# 5     Achievement striving  2007    0.391612  0.391612   Pop        2
# 6     Achievement striving  2017    0.463470  0.463470   Pop        2
# 7           Activity level  1957    0.070753  0.070753   Pop        3
# 8           Activity level  1967    0.242325  0.242325   Pop        3
# 9           Activity level  1977    0.274652  0.274652   Pop        3
# 10          Activity level  1987    0.386946  0.386946   Pop        3
# 11          Activity level  1997    0.093448  0.093448   Pop        3
# 12          Activity level  2007    0.215199  0.215199   Pop        3
# 13          Activity level  2017    0.424038  0.424038   Pop        3
# 14         Adventurousness  1957    0.419209  0.419209   Pop        1
# 15         Adventurousness  1967    0.656106  0.656106   Pop        1
# 16         Adventurousness  1977    0.713257  0.713257   Pop        1
# 17         Adventurousness  1987    0.657750  0.657750   Pop        1
# 18         Adventurousness  1997    0.774223  0.774223   Pop        1
# 19         Adventurousness  2007    0.789262  0.789262   Pop        1
# 20         Adventurousness  2017    0.913003  0.913003   Pop        1
# 21                Altruism  1957    0.617536  0.617536   Pop        4
# 22                Altruism  1967    0.952677  0.952677   Pop        4
# 23                Altruism  1977    0.932543  0.932543   Pop        4
# 24                Altruism  1987    0.698302  0.698302   Pop        4
# 25                Altruism  1997    0.767263  0.767263   Pop        4
# 26                Altruism  2007    0.949093  0.949093   Pop        4
# 27                Altruism  2017    0.781625  0.781625   Pop        4
# 28      Artistic interests  1957    0.952567  0.952567   Pop        6
# 29      Artistic interests  1967    0.966113  0.966113   Pop        6
# ..                     ...   ...         ...       ...   ...      ...
# 180          Self-efficacy  2007    0.186355  0.186355   Pop       27
# 181          Self-efficacy  2017    0.374745  0.374745   Pop       27
# 182  Susceptible to stress  1957    0.541732  0.541732   Pop       30
# 183  Susceptible to stress  1967    0.565897  0.565897   Pop       30
# 184  Susceptible to stress  1977    0.839845  0.839845   Pop       30
# 185  Susceptible to stress  1987    0.325169  0.325169   Pop       30
# 186  Susceptible to stress  1997    0.734967  0.734967   Pop       30
# 187  Susceptible to stress  2007    0.348741  0.348741   Pop       30
# 188  Susceptible to stress  2017    0.224006  0.224006   Pop       30
# 189               Sympathy  1957    0.898406  0.898406   Pop       24
# 190               Sympathy  1967    0.980114  0.980114   Pop       24
# 191               Sympathy  1977    0.966230  0.966230   Pop       24
# 192               Sympathy  1987    0.863522  0.863522   Pop       24
# 193               Sympathy  1997    0.808437  0.808437   Pop       24
# 194               Sympathy  2007    0.942172  0.942172   Pop       24
# 195               Sympathy  2017    0.716432  0.716432   Pop       24
# 196                  Trust  1957    0.051975  0.051975   Pop       29
# 197                  Trust  1967    0.190821  0.190821   Pop       29
# 198                  Trust  1977    0.134079  0.134079   Pop       29
# 199                  Trust  1987    0.326971  0.326971   Pop       29
# 200                  Trust  1997    0.071042  0.071042   Pop       29
# 201                  Trust  2007    0.310049  0.310049   Pop       29
# 202                  Trust  2017    0.146317  0.146317   Pop       29
# 203         Uncompromising  1957    0.860910  0.860910   Pop       19
# 204         Uncompromising  1967    0.946642  0.946642   Pop       19
# 205         Uncompromising  1977    0.883186  0.883186   Pop       19
# 206         Uncompromising  1987    0.892281  0.892281   Pop       19
# 207         Uncompromising  1997    0.975414  0.975414   Pop       19
# 208         Uncompromising  2007    0.967845  0.967845   Pop       19
# 209         Uncompromising  2017    0.941394  0.941394   Pop       19
#
#         color
# 0     #3cb44b
# 1     #3cb44b
# 2     #3cb44b
# 3     #3cb44b
# 4     #3cb44b
# 5     #3cb44b
# 6     #3cb44b
# 7     #ffe119
# 8     #ffe119
# 9     #ffe119
# 10    #ffe119
# 11    #ffe119
# 12    #ffe119
# 13    #ffe119
# 14    #e6194b
# 15    #e6194b
# 16    #e6194b
# 17    #e6194b
# 18    #e6194b
# 19    #e6194b
# 20    #e6194b
# 21    #0082c8
# 22    #0082c8
# 23    #0082c8
# 24    #0082c8
# 25    #0082c8
# 26    #0082c8
# 27    #0082c8
# 28    #911eb4
# 29    #911eb4
# ..        ...
# 180   #ECF190
# 181   #ECF190
# 182  ##700C05
# 183  ##700C05
# 184  ##700C05
# 185  ##700C05
# 186  ##700C05
# 187  ##700C05
# 188  ##700C05
# 189   #074D26
# 190   #074D26
# 191   #074D26
# 192   #074D26
# 193   #074D26
# 194   #074D26
# 195   #074D26
# 196   #662584
# 197   #662584
# 198   #662584
# 199   #662584
# 200   #662584
# 201   #662584
# 202   #662584
# 203   #000080
# 204   #000080
# 205   #000080
# 206   #000080
# 207   #000080
# 208   #000080
# 209   #000080
#
# [210 rows x 7 columns]

# %%
dataset.rename(index= str, columns = {'Emotion': 'emotion', 'years':'year'})
dataset.head()
# Out:
#                 Emotion years  percentile      size genre  postion    color
# 0  Achievement striving  1957    0.198338  0.198338   Pop        2  #3cb44b
# 1  Achievement striving  1967    0.332933  0.332933   Pop        2  #3cb44b
# 2  Achievement striving  1977    0.246229  0.246229   Pop        2  #3cb44b
# 3  Achievement striving  1987    0.423422  0.423422   Pop        2  #3cb44b
# 4  Achievement striving  1997    0.232846  0.232846   Pop        2  #3cb44b

# %%
dataset.to_csv("country_bub_form.csv")
