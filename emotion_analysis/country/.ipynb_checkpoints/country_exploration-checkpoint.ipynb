# %%
import pandas as pd 
import json
import matplotlib.pyplot as plt 
import numpy as np

# %%
with open('country_lyr_results/one_country_results.json') as json_data:
    one = json.load(json_data)
with open('country_lyr_results/two_country_results.json') as json_data:
    two = json.load(json_data)
with open('country_lyr_results/three_country_results.json') as json_data:
    three = json.load(json_data)
with open('country_lyr_results/four_country_results.json') as json_data:
    four = json.load(json_data)
with open('country_lyr_results/five_country_results.json') as json_data:
    five = json.load(json_data)
with open('country_lyr_results/six_country_results.json') as json_data:
    six = json.load(json_data)
with open('country_lyr_results/seven_country_results.json') as json_data:
    seven = json.load(json_data)

# %%
one_personality = pd.DataFrame(one["personality"])
one_personality
# Out:
#       category                                           children  \
# 0  personality  [{'trait_id': 'facet_adventurousness', 'name':...
# 1  personality  [{'trait_id': 'facet_achievement_striving', 'n...
# 2  personality  [{'trait_id': 'facet_activity_level', 'name': ...
# 3  personality  [{'trait_id': 'facet_altruism', 'name': 'Altru...
# 4  personality  [{'trait_id': 'facet_anger', 'name': 'Fiery', ...
#
#                 name  percentile  raw_score  significant  \
# 0           Openness    0.751237   0.770311         True
# 1  Conscientiousness    0.167363   0.583059         True
# 2       Extraversion    0.226104   0.517461         True
# 3      Agreeableness    0.675567   0.760300         True
# 4    Emotional range    0.517495   0.469839         True
#
#                  trait_id
# 0           big5_openness
# 1  big5_conscientiousness
# 2       big5_extraversion
# 3      big5_agreeableness
# 4        big5_neuroticism

# %%
two_personality = pd.DataFrame(two["personality"])
three_personality = pd.DataFrame(three["personality"])
four_personality = pd.DataFrame(four["personality"])
five_personality = pd.DataFrame(five["personality"])
six_personality = pd.DataFrame(six["personality"])
seven_personality = pd.DataFrame(seven["personality"])

# %%
df1 = one_personality[["name","percentile"]]
df2 = two_personality[["name","percentile"]]
df3 = three_personality[["name","percentile"]]
df4 = four_personality[["name","percentile"]]
df5 = five_personality[["name","percentile"]]
df6 = six_personality[["name","percentile"]]
df7 = seven_personality[["name","percentile"]]

# %%
combined_scores_df = df1.merge(df2,on='name').merge(df3,on='name').merge(df4,on='name').merge(df5,on='name').merge(df6,on='name').merge(df7,on='name')

# %%
combined_scores_df
# Out:
#                 name  percentile_x  percentile_y  percentile_x  percentile_y  \
# 0           Openness      0.751237      0.700065      0.833782      0.748763
# 1  Conscientiousness      0.167363      0.427521      0.388457      0.493214
# 2       Extraversion      0.226104      0.239256      0.550600      0.556381
# 3      Agreeableness      0.675567      0.731840      0.826165      0.639540
# 4    Emotional range      0.517495      0.441683      0.214927      0.508270
#
#    percentile_x  percentile_y  percentile
# 0      0.708892      0.799742    0.542467
# 1      0.419960      0.628508    0.780131
# 2      0.335952      0.714704    0.797396
# 3      0.957429      0.919623    0.814854
# 4      0.398090      0.677815    0.646056

# %%
values = combined_scores_df.drop('name', axis=1)
values
# Out:
#    percentile_x  percentile_y  percentile_x  percentile_y  percentile_x  \
# 0      0.751237      0.700065      0.833782      0.748763      0.708892
# 1      0.167363      0.427521      0.388457      0.493214      0.419960
# 2      0.226104      0.239256      0.550600      0.556381      0.335952
# 3      0.675567      0.731840      0.826165      0.639540      0.957429
# 4      0.517495      0.441683      0.214927      0.508270      0.398090
#
#    percentile_y  percentile
# 0      0.799742    0.542467
# 1      0.628508    0.780131
# 2      0.714704    0.797396
# 3      0.919623    0.814854
# 4      0.677815    0.646056

# %%
timepoint = [1947,1957,1967,1987,1997,2007,2017]
length = np.arange(0,len(values),1)
labels = ["Openness",
          "Consienctiousness",
          "Extraversion",
          "Aggreeableness",
          "Emotional range"]

percentile=[]

for row in values.iterrows():
    index, data = row
    percentile.append(data.tolist())

# %%
plt.figure(figsize=(10,10))
[plt.scatter(timepoint, percentile[x]) for x in length]
plt.legend(loc='upper left', shadow=True)
[plt.plot(timepoint, percentile[x], linestyle= 'dashed', linewidth=1, label = labels[x]) for x in length]
plt.title("Emotional Response of Country Hits over Time")
plt.xlabel("Time")
plt.ylabel("Percentile Score")
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <h1><strong> In depth analysis complete data retrieval </strong></h1>

# %%
one_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in one["personality"] ]
one_full = pd.DataFrame(one_depth)
one_full.columns= [["Emotion", "1957"]]

# %%
two_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in two["personality"]]
two_full = pd.DataFrame(two_depth)
two_full.columns= [["Emotion", "1967"]]
three_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in three["personality"] ]
three_full = pd.DataFrame(three_depth)
three_full.columns= [["Emotion", "1977"]]
four_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in four["personality"] ]
four_full = pd.DataFrame(four_depth)
four_full.columns= [["Emotion", "1987"]]
five_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in five["personality"] ]
five_full = pd.DataFrame(five_depth)
five_full.columns= [["Emotion", "1997"]]
six_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in six["personality"] ]
six_full = pd.DataFrame(six_depth)
six_full.columns= [["Emotion", "2007"]]
seven_depth = [[i["children"][j]["name"], i["children"][j]["percentile"]] for j in range(6) for i in seven["personality"] ]
seven_full = pd.DataFrame(seven_depth)
seven_full.columns= [["Emotion", "2017"]]

# %%
combined = one_full.merge(two_full).merge(three_full).merge(four_full).merge(five_full).merge(six_full).merge(seven_full)
combined
# Out:
#                   Emotion      1957      1967      1977      1987      1997  \
# 0         Adventurousness  0.419209  0.656106  0.713257  0.657750  0.774223
# 1    Achievement striving  0.198338  0.332933  0.246229  0.423422  0.232846
# 2          Activity level  0.070753  0.242325  0.274652  0.386946  0.093448
# 3                Altruism  0.617536  0.952677  0.932543  0.698302  0.767263
# 4                   Fiery  0.366635  0.236679  0.404380  0.242286  0.220092
# 5      Artistic interests  0.952567  0.966113  0.993957  0.948897  0.987051
# 6            Cautiousness  0.350478  0.316309  0.108201  0.469585  0.477823
# 7           Assertiveness  0.262479  0.296851  0.265433  0.406554  0.118832
# 8             Cooperation  0.428054  0.568653  0.425332  0.449816  0.741578
# 9          Prone to worry  0.265751  0.311579  0.652427  0.234461  0.345017
# 10           Emotionality  0.779701  0.968929  0.993901  0.818191  0.954436
# 11            Dutifulness  0.244809  0.573516  0.279596  0.363267  0.469006
# 12           Cheerfulness  0.843149  0.889790  0.919209  0.917868  0.936883
# 13                Modesty  0.768131  0.952343  0.842506  0.727188  0.943907
# 14             Melancholy  0.656347  0.796982  0.923414  0.543163  0.633252
# 15            Imagination  0.774777  0.847428  0.981912  0.894250  0.728428
# 16            Orderliness  0.602848  0.450091  0.292180  0.719417  0.463899
# 17     Excitement-seeking  0.519653  0.588398  0.873147  0.699738  0.520615
# 18         Uncompromising  0.860910  0.946642  0.883186  0.892281  0.975414
# 19           Immoderation  0.707053  0.742497  0.865174  0.691175  0.628511
# 20              Intellect  0.925981  0.899389  0.920334  0.778564  0.749384
# 21        Self-discipline  0.242384  0.305765  0.135178  0.460285  0.322776
# 22               Outgoing  0.404178  0.618477  0.494417  0.793354  0.314083
# 23               Sympathy  0.898406  0.980114  0.966230  0.863522  0.808437
# 24     Self-consciousness  0.368925  0.244523  0.402067  0.158536  0.470274
# 25  Authority-challenging  0.476386  0.310181  0.501954  0.438899  0.461346
# 26          Self-efficacy  0.142488  0.190840  0.211125  0.363249  0.052425
# 27         Gregariousness  0.213024  0.466638  0.575564  0.819443  0.214140
# 28                  Trust  0.051975  0.190821  0.134079  0.326971  0.071042
# 29  Susceptible to stress  0.541732  0.565897  0.839845  0.325169  0.734967
#
#         2007      2017
# 0   0.789262  0.913003
# 1   0.391612  0.463470
# 2   0.215199  0.424038
# 3   0.949093  0.781625
# 4   0.047625  0.164191
# 5   0.961926  0.956611
# 6   0.567646  0.309557
# 7   0.455018  0.554704
# 8   0.773606  0.507215
# 9   0.138555  0.114335
# 10  0.976508  0.857226
# 11  0.594128  0.376073
# 12  0.950333  0.997073
# 13  0.873517  0.761543
# 14  0.365453  0.321872
# 15  0.652173  0.718518
# 16  0.545229  0.752254
# 17  0.563789  0.862802
# 18  0.967845  0.941394
# 19  0.749250  0.610284
# 20  0.877065  0.676429
# 21  0.427516  0.748113
# 22  0.687902  0.915825
# 23  0.942172  0.716432
# 24  0.190374  0.069760
# 25  0.578633  0.180439
# 26  0.186355  0.374745
# 27  0.659183  0.883686
# 28  0.310049  0.146317
# 29  0.348741  0.224006

# %%
combined.to_csv("country_combined.csv")
